# %%
# Check if a year is leap year
year = 2024
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Leap Year

# %%
# Find the greatest of three numbers
a, b, c = 12, 7, 25
if a > b and a > c:
    print("a is greatest")
elif b > c:
    print("b is greatest")
else:
    print("c is greatest")
# Out:
# c is greatest

# %%
 # Check if a number is divisible by 5
num = 30
if num % 5 == 0:
    print("Divisible by 5")
else:
    print("Not Divisible by 5")
# Out:
# Divisible by 5

# %%
 # Check if a character is a vowel
ch = 'p'
if ch in 'aeiouAEIOU':
    print("Vowel")
else:
    print("Consonant")
# Out:
# Consonant

# %%
# Check if a number is in range 1-100
num = 45
if 1 <= num <= 100:
    print("In range")
else:
    print("Out of range")
# Out:
# In range

# %%
# Check if a number is multiple of 3 and 5
num = 15
if num % 3 == 0 and num % 5 == 0:
    print("Multiple of 3 and 5")
else:
    print("Not a multiple of 3 and 5")
# Out:
# Multiple of 3 and 5

# %%
side1=int(input("enter the first side of triangle"))
side2=int(input("enter the second side of triangle"))
side3=int(input("enter the third side of triangle"))
if side1==side2 and side2==side3:
    print("equil.")
elif side1==side2 or side2==side3 or side3==side1:
    print("isoc.")
else:
    print("scalan")
# Out:
# enter the first side of triangle 4
# enter the second side of triangle 4
# enter the third side of triangle 5
# isoc.

# %%
#login Page
correct_username="mohit"
correct_password="1234"
username=input("enter the username")
password=input("enter the password")
if username==correct_username and password==correct_password:
    print("login successfull")
else:
    print("invalid credentials")
# Out:
# enter the username mohit
# enter the password 3456
# invalid credentials

# %%
# Grade Calculation with Nested If
marks = int(input("Enter marks: "))
if marks >= 90:
    grade = "A+"
elif marks >= 75:
    grade = "A"
elif marks >= 60:
    grade = "B"
elif marks >= 40:
    grade = "C"
else:
    grade = "Fail"
print("Grade:", grade)
# Out:
# Enter marks:  39
# Grade: Fail

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
op = input("Enter operator (+,-,*,/): ")

if op == "+":
    print(a + b)
elif op == "-":
    print(a - b)
elif op == "*":
    print(a * b)
elif op == "/":
    if b != 0:
        print(a / b)
    else:
        print("Division by Zero not allowed")
else:
    print("Invalid Operator")
# Out:
# Enter first number:  55
# Enter second number:  5
# Enter operator (+,-,*,/):  *
# 275

# %%
# # Inputs
# // A user is shopping on an e-commerce site:

# // If cartValue ≥ 5000 AND isPrimeMember → 20% discount
# // Else if cartValue ≥ 5000 but not Prime → 10% discount
# // If today is “FestivalDay” → add extra 5% discount on top of above.
# // If using “Credit Card” → add cashback of 200.
# // Final price must never go below 3000 (apply a final check).

cartValue = int(input("Enter cart value: "))
isPrimeMember = input("Are you a Prime Member? (yes/no): ").lower() == "yes"
isFestivalDay = input("Is today Festival Day? (yes/no): ").lower() == "yes"
paymentMode = input("Enter payment mode (Credit/Debit/UPI): ").lower()


discount = 0
if cartValue >= 5000 and isPrimeMember:
    discount = 20
elif cartValue >= 5000 and not isPrimeMember:
    discount = 10


# Step 2: Extra discount if Festival Day
if isFestivalDay:
    discount += 5  #discount=discount+5

# Apply discount
finalPrice = cartValue - (cartValue * discount / 100)

# Step 3: Cashback if payment mode is Credit Card
cashback = 0
if paymentMode == "credit":
    cashback = 200


# Step 4: Final check (cannot go below 3000)
if finalPrice < 3000:
    finalPrice = 3000

# Output
print("Final Price to Pay:", finalPrice)
print("Cashback :",cashback)
# Out:
# Enter cart value:  6000
# Are you a Prime Member? (yes/no):  yes
# Is today Festival Day? (yes/no):  yes
# Enter payment mode (Credit/Debit/UPI):  credit
# Final Price to Pay: 4500.0
# Cashback : 200

# %%
ch='a'
if 'a'<=ch<='z' or 'A'<=ch<='Z':
    print("alpha")
elif 0<=ch<=9:
    print("digit")
else:
    print("symbols")
# Out:
# alpha

# %%
import math
x=28
y=math.sqrt(x)
if y==int(y):
   print("perfect")
else:
  print("not")
# Out:
# not
